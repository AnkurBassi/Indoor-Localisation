# %% [markdown]
# Go to Google Drive link below
#
# Find the folder "indoor-location-competition" -> Right Click the folder -> Click Organize->"Add shortcut to Drive" -> A window pops->go to All location and select->MyDrive
#
# https://drive.google.com/drive/folders/14ZqnJDlpgc5O8Dcet6HYHZT1_8uJIwel?usp=drive_link

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cp -var /content/drive/MyDrive/indoor-location-competition/ /content
# Out:
# '/content/drive/MyDrive/indoor-location-competition/' -> '/content/indoor-location-competition'
# '/content/drive/MyDrive/indoor-location-competition/indoor-location-navigation.zip' -> '/content/indoor-location-competition/indoor-location-navigation.zip'
# '/content/drive/MyDrive/indoor-location-competition/test.zip' -> '/content/indoor-location-competition/test.zip'
# '/content/drive/MyDrive/indoor-location-competition/test_site_dict.pkl' -> '/content/indoor-location-competition/test_site_dict.pkl'
# '/content/drive/MyDrive/indoor-location-competition/iln-x-y-training-and-inference-part-no-pp.ipynb' -> '/content/indoor-location-competition/iln-x-y-training-and-inference-part-no-pp.ipynb'
# '/content/drive/MyDrive/indoor-location-competition/ILN_631dat_df_wifi_all.pkl' -> '/content/indoor-location-competition/ILN_631dat_df_wifi_all.pkl'
# '/content/drive/MyDrive/indoor-location-competition/test_ts_lag.csv' -> '/content/indoor-location-competition/test_ts_lag.csv'
# '/content/drive/MyDrive/indoor-location-competition/sample_submission.csv' -> '/content/indoor-location-competition/sample_submission.csv'
# '/content/drive/MyDrive/indoor-location-competition/LICENSE' -> '/content/indoor-location-competition/LICENSE'
# '/content/drive/MyDrive/indoor-location-competition/compute_f.py' -> '/content/indoor-location-competition/compute_f.py'
# '/content/drive/MyDrive/indoor-location-competition/README.md' -> '/content/indoor-location-competition/README.md'
# '/content/drive/MyDrive/indoor-location-competition/.gitignore' -> '/content/indoor-location-competition/.gitignore'
# '/content/drive/MyDrive/indoor-location-competition/visualize_f.py' -> '/content/indoor-location-competition/visualize_f.py'
# '/content/drive/MyDrive/indoor-location-competition/main.py' -> '/content/indoor-location-competition/main.py'
# '/content/drive/MyDrive/indoor-location-competition/io_f.py' -> '/content/indoor-location-competition/io_f.py'
# '/content/drive/MyDrive/indoor-location-competition/webinar.pdf' -> '/content/indoor-location-competition/webinar.pdf'
# '/content/drive/MyDrive/indoor-location-competition/__pycache__' -> '/content/indoor-location-competition/__pycache__'
# '/content/drive/MyDrive/indoor-location-competition/__pycache__/visualize_f.cpython-310.pyc' -> '/content/indoor-location-competition/__pycache__/visualize_f.cpython-310.pyc'
# '/content/drive/MyDrive/indoor-location-competition/__pycache__/compute_f.cpython-310.pyc' -> '/content/indoor-location-competition/__pycache__/compute_f.cpython-310.pyc'
# '/content/drive/MyDrive/indoor-location-competition/data_10.csv' -> '/content/indoor-location-competition/data_10.csv'
# '/content/drive/MyDrive/indoor-location-competition/.git' -> '/content/indoor-location-competition/.git'
# '/content/drive/MyDrive/indoor-location-competition/.git/branches' -> '/content/indoor-location-competition/.git/branches'
# '/content/drive/MyDrive/indoor-location-competition/.git/objects' -> '/content/indoor-location-competition/.git/objects'
# '/content/drive/MyDrive/indoor-location-competition/.git/objects/info' -> '/content/indoor-location-competition/.git/objects/info'
# '/content/drive/MyDrive/indoor-location-competition/.git/objects/pack' -> '/content/indoor-location-competition/.git/objects/pack'
# '/content/drive/MyDrive/indoor-location-competition/.git/objects/pack/pack-30974156bfeb13ebf46cc50cfcf3409a533de3dc.pack' -> '/content/indoor-location-competition/.git/objects/pack/pack-30974156bfeb13ebf46cc50cfcf3409a533de3dc.pack'
# '/content/drive/MyDrive/indoor-location-competition/.git/objects/pack/pack-30974156bfeb13ebf46cc50cfcf3409a533de3dc.idx' -> '/content/indoor-location-competition/.git/objects/pack/pack-30974156bfeb13ebf46cc50cfcf3409a533de3dc.idx'
# '/content/drive/MyDrive/indoor-location-competition/.git/description' -> '/content/indoor-location-competition/.git/description'
# '/content/drive/MyDrive/indoor-location-competition/.git/info' -> '/content/indoor-location-competition/.git/info'
# '/content/drive/MyDrive/indoor-location-competition/.git/info/exclude' -> '/content/indoor-location-competition/.git/info/exclude'
# '/content/drive/MyDrive/indoor-location-competition/.git/hooks' -> '/content/indoor-location-competition/.git/hooks'
# '/content/drive/MyDrive/indoor-location-competition/.git/hooks/pre-push.sample' -> '/content/indoor-location-competition/.git/hooks/pre-push.sample'
# '/content/drive/MyDrive/indoor-location-competition/.git/hooks/pre-rebase.sample' -> '/content/indoor-location-competition/.git/hooks/pre-rebase.sample'
# '/content/drive/MyDrive/indoor-location-competition/.git/hooks/pre-receive.sample' -> '/content/indoor-location-competition/.git/hooks/pre-receive.sample'
# '/content/drive/MyDrive/indoor-location-competition/.git/hooks/pre-merge-commit.sample' -> '/content/indoor-location-competition/.git/hooks/pre-merge-commit.sample'
# '/content/drive/MyDrive/indoor-location-competition/.git/hooks/fsmonitor-watchman.sample' -> '/content/indoor-location-competition/.git/hooks/fsmonitor-watchman.sample'
# '/content/drive/MyDrive/indoor-location-competition/.git/hooks/applypatch-msg.sample' -> '/content/indoor-location-competition/.git/hooks/applypatch-msg.sample'
# '/content/drive/MyDrive/indoor-location-competition/.git/hooks/update.sample' -> '/content/indoor-location-competition/.git/hooks/update.sample'
# '/content/drive/MyDrive/indoor-location-competition/.git/hooks/post-update.sample' -> '/content/indoor-location-competition/.git/hooks/post-update.sample'
# '/content/drive/MyDrive/indoor-location-competition/.git/hooks/prepare-commit-msg.sample' -> '/content/indoor-location-competition/.git/hooks/prepare-commit-msg.sample'
# '/content/drive/MyDrive/indoor-location-competition/.git/hooks/pre-commit.sample' -> '/content/indoor-location-competition/.git/hooks/pre-commit.sample'
# '/content/drive/MyDrive/indoor-location-competition/.git/hooks/push-to-checkout.sample' -> '/content/indoor-location-competition/.git/hooks/push-to-checkout.sample'
# '/content/drive/MyDrive/indoor-location-competition/.git/hooks/commit-msg.sample' -> '/content/indoor-location-competition/.git/hooks/commit-msg.sample'
# '/content/drive/MyDrive/indoor-location-competition/.git/hooks/pre-applypatch.sample' -> '/content/indoor-location-competition/.git/hooks/pre-applypatch.sample'
# '/content/drive/MyDrive/indoor-location-competition/.git/refs' -> '/content/indoor-location-competition/.git/refs'
# '/content/drive/MyDrive/indoor-location-competition/.git/refs/tags' -> '/content/indoor-location-competition/.git/refs/tags'
# '/content/drive/MyDrive/indoor-location-competition/.git/refs/remotes' -> '/content/indoor-location-competition/.git/refs/remotes'
# '/content/drive/MyDrive/indoor-location-competition/.git/refs/remotes/origin' -> '/content/indoor-location-competition/.git/refs/remotes/origin'
# '/content/drive/MyDrive/indoor-location-competition/.git/refs/remotes/origin/HEAD' -> '/content/indoor-location-competition/.git/refs/remotes/origin/HEAD'
# '/content/drive/MyDrive/indoor-location-competition/.git/refs/heads' -> '/content/indoor-location-competition/.git/refs/heads'
# '/content/drive/MyDrive/indoor-location-competition/.git/refs/heads/master' -> '/content/indoor-location-competition/.git/refs/heads/master'
# '/content/drive/MyDrive/indoor-location-competition/.git/packed-refs' -> '/content/indoor-location-competition/.git/packed-refs'
# '/content/drive/MyDrive/indoor-location-competition/.git/HEAD' -> '/content/indoor-location-competition/.git/HEAD'
# '/content/drive/MyDrive/indoor-location-competition/.git/logs' -> '/content/indoor-location-competition/.git/logs'
# '/content/drive/MyDrive/indoor-location-competition/.git/logs/HEAD' -> '/content/indoor-location-competition/.git/logs/HEAD'
# '/content/drive/MyDrive/indoor-location-competition/.git/logs/refs' -> '/content/indoor-location-competition/.git/logs/refs'
# '/content/drive/MyDrive/indoor-location-competition/.git/logs/refs/remotes' -> '/content/indoor-location-competition/.git/logs/refs/remotes'
# '/content/drive/MyDrive/indoor-location-competition/.git/logs/refs/remotes/origin' -> '/content/indoor-location-competition/.git/logs/refs/remotes/origin'
# '/content/drive/MyDrive/indoor-location-competition/.git/logs/refs/remotes/origin/HEAD' -> '/content/indoor-location-competition/.git/logs/refs/remotes/origin/HEAD'
# '/content/drive/MyDrive/indoor-location-competition/.git/logs/refs/heads' -> '/content/indoor-location-competition/.git/logs/refs/heads'
# '/content/drive/MyDrive/indoor-location-competition/.git/logs/refs/heads/master' -> '/content/indoor-location-competition/.git/logs/refs/heads/master'
# '/content/drive/MyDrive/indoor-location-competition/.git/config' -> '/content/indoor-location-competition/.git/config'
# '/content/drive/MyDrive/indoor-location-competition/.git/index' -> '/content/indoor-location-competition/.git/index'
# '/content/drive/MyDrive/indoor-location-competition/data' -> '/content/indoor-location-competition/data'
# '/content/drive/MyDrive/indoor-location-competition/data/site2' -> '/content/indoor-location-competition/data/site2'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1' -> '/content/indoor-location-competition/data/site2/B1'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/geojson_map.json' -> '/content/indoor-location-competition/data/site2/B1/geojson_map.json'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/floor_info.json' -> '/content/indoor-location-competition/data/site2/B1/floor_info.json'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/floor_image.png' -> '/content/indoor-location-competition/data/site2/B1/floor_image.png'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files' -> '/content/indoor-location-competition/data/site2/B1/path_data_files'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511e3d48f840006f148ec.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511e3d48f840006f148ec.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd506a6d48f840006f14810.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd506a6d48f840006f14810.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd506b9d48f840006f1481e.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd506b9d48f840006f1481e.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511df50e04e0006f56380.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511df50e04e0006f56380.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd506abd48f840006f14812.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd506abd48f840006f14812.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd5118050e04e0006f5636a.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd5118050e04e0006f5636a.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd506b750e04e0006f56297.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd506b750e04e0006f56297.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd506b050e04e0006f56291.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd506b050e04e0006f56291.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd506c050e04e0006f562a3.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd506c050e04e0006f562a3.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd506bd50e04e0006f5629f.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd506bd50e04e0006f5629f.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511ca50e04e0006f56370.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511ca50e04e0006f56370.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511e250e04e0006f56382.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511e250e04e0006f56382.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511e550e04e0006f56386.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511e550e04e0006f56386.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd506ba50e04e0006f5629b.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd506ba50e04e0006f5629b.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511d5d48f840006f148e2.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511d5d48f840006f148e2.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511e1d48f840006f148ea.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511e1d48f840006f148ea.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd506c350e04e0006f562a7.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd506c350e04e0006f562a7.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd506c150e04e0006f562a5.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd506c150e04e0006f562a5.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511e5d48f840006f148ee.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511e5d48f840006f148ee.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511dcd48f840006f148e6.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511dcd48f840006f148e6.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd506ac50e04e0006f5628f.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd506ac50e04e0006f5628f.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511d5d48f840006f148e0.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511d5d48f840006f148e0.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd506c2d48f840006f14826.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd506c2d48f840006f14826.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511d650e04e0006f56376.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511d650e04e0006f56376.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511dad48f840006f148e4.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511dad48f840006f148e4.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd506b850e04e0006f56299.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd506b850e04e0006f56299.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd506b8d48f840006f1481c.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd506b8d48f840006f1481c.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511d950e04e0006f5637a.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511d950e04e0006f5637a.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511d550e04e0006f56374.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511d550e04e0006f56374.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511bcd48f840006f148de.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511bcd48f840006f148de.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511d350e04e0006f56372.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511d350e04e0006f56372.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd5069f50e04e0006f56287.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd5069f50e04e0006f56287.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511abd48f840006f148dc.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511abd48f840006f148dc.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511de50e04e0006f5637e.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511de50e04e0006f5637e.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd506c1d48f840006f14824.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd506c1d48f840006f14824.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd5069f50e04e0006f56289.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd5069f50e04e0006f56289.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd506b6d48f840006f1481a.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd506b6d48f840006f1481a.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511c850e04e0006f5636e.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511c850e04e0006f5636e.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd506bc50e04e0006f5629d.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd506bc50e04e0006f5629d.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd506bed48f840006f14820.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd506bed48f840006f14820.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd61e6f7da0810006e2405b.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd61e6f7da0810006e2405b.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511e7d48f840006f148f0.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511e7d48f840006f148f0.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511eed48f840006f148f8.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511eed48f840006f148f8.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd61f617da0810006e2407b.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd61f617da0810006e2407b.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd61bde7da0810006e24031.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd61bde7da0810006e24031.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd61f5e7da0810006e24077.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd61f5e7da0810006e24077.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd61a487da0810006e24019.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd61a487da0810006e24019.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511ecd48f840006f148f6.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511ecd48f840006f148f6.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511ee50e04e0006f56390.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511ee50e04e0006f56390.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd61d6b7da0810006e24046.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd61d6b7da0810006e24046.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511efd48f840006f148fa.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511efd48f840006f148fa.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd61bddd48f840006f14d50.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd61bddd48f840006f14d50.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd61e6ed48f840006f14d7a.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd61e6ed48f840006f14d7a.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd61bdbd48f840006f14d4e.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd61bdbd48f840006f14d4e.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd61d68d48f840006f14d6b.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd61d68d48f840006f14d6b.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511e850e04e0006f56388.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511e850e04e0006f56388.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd61e6c7da0810006e24059.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd61e6c7da0810006e24059.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd61d6bd48f840006f14d6d.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd61d6bd48f840006f14d6d.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd61be7d48f840006f14d52.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd61be7d48f840006f14d52.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd61f5f7da0810006e24079.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd61f5f7da0810006e24079.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd61bdc7da0810006e2402f.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd61bdc7da0810006e2402f.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511ed50e04e0006f5638e.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511ed50e04e0006f5638e.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd61bdf7da0810006e24033.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd61bdf7da0810006e24033.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd61a4ad48f840006f14d32.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd61a4ad48f840006f14d32.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511e9d48f840006f148f2.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511e9d48f840006f148f2.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd61d697da0810006e24043.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd61d697da0810006e24043.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd511ebd48f840006f148f4.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd511ebd48f840006f148f4.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd6190fd48f840006f14d2c.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd6190fd48f840006f14d2c.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd61f60d48f840006f14d8a.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd61f60d48f840006f14d8a.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/B1/path_data_files/5dd619177da0810006e2400e.txt' -> '/content/indoor-location-competition/data/site2/B1/path_data_files/5dd619177da0810006e2400e.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1' -> '/content/indoor-location-competition/data/site2/F1'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/geojson_map.json' -> '/content/indoor-location-competition/data/site2/F1/geojson_map.json'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/floor_image.png' -> '/content/indoor-location-competition/data/site2/F1/floor_image.png'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/floor_info.json' -> '/content/indoor-location-competition/data/site2/F1/floor_info.json'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files' -> '/content/indoor-location-competition/data/site2/F1/path_data_files'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c8744333f00067aa0d6.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c8744333f00067aa0d6.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c8127889b0006b76856.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c8127889b0006b76856.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c8327889b0006b76858.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c8327889b0006b76858.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c6e44333f00067aa0c2.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c6e44333f00067aa0c2.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c7627889b0006b76854.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c7627889b0006b76854.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c8a27889b0006b7685e.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c8a27889b0006b7685e.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c7844333f00067aa0ca.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c7844333f00067aa0ca.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c8244333f00067aa0d2.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c8244333f00067aa0d2.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c6e44333f00067aa0c0.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c6e44333f00067aa0c0.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c8627889b0006b7685a.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c8627889b0006b7685a.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c7144333f00067aa0c4.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c7144333f00067aa0c4.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c6a27889b0006b7684a.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c6a27889b0006b7684a.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c7527889b0006b76852.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c7527889b0006b76852.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c7c44333f00067aa0ce.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c7c44333f00067aa0ce.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c7327889b0006b76850.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c7327889b0006b76850.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c8827889b0006b7685c.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c8827889b0006b7685c.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c6944333f00067aa0bc.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c6944333f00067aa0bc.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c7027889b0006b7684e.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c7027889b0006b7684e.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c8444333f00067aa0d4.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c8444333f00067aa0d4.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c7844333f00067aa0cc.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c7844333f00067aa0cc.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c6927889b0006b76848.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c6927889b0006b76848.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c6844333f00067aa0ba.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c6844333f00067aa0ba.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c6b44333f00067aa0be.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c6b44333f00067aa0be.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c7444333f00067aa0c6.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c7444333f00067aa0c6.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c7e44333f00067aa0d0.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c7e44333f00067aa0d0.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c6c27889b0006b7684c.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c6c27889b0006b7684c.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c7644333f00067aa0c8.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c7644333f00067aa0c8.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd61666d48f840006f14d01.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd61666d48f840006f14d01.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c8e44333f00067aa0da.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c8e44333f00067aa0da.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c9a27889b0006b76864.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c9a27889b0006b76864.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c9244333f00067aa0de.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c9244333f00067aa0de.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd365fa27889b0006b768ab.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd365fa27889b0006b768ab.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd4a18927889b0006b77593.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd4a18927889b0006b77593.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c9b44333f00067aa0e2.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c9b44333f00067aa0e2.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c8d44333f00067aa0d8.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c8d44333f00067aa0d8.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd365fb27889b0006b768ad.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd365fb27889b0006b768ad.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd6139bd48f840006f14cbf.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd6139bd48f840006f14cbf.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd62763d48f840006f14ddc.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd62763d48f840006f14ddc.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd365fd27889b0006b768b1.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd365fd27889b0006b768b1.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd3660327889b0006b768b5.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd3660327889b0006b768b5.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c8f27889b0006b76860.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c8f27889b0006b76860.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd3660244333f00067aa126.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd3660244333f00067aa126.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd62780d48f840006f14de2.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd62780d48f840006f14de2.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd6177fd48f840006f14d13.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd6177fd48f840006f14d13.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd3660144333f00067aa124.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd3660144333f00067aa124.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd365ff44333f00067aa120.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd365ff44333f00067aa120.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd61660d48f840006f14cff.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd61660d48f840006f14cff.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd365f727889b0006b768a9.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd365f727889b0006b768a9.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd365e927889b0006b768a3.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd365e927889b0006b768a3.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd614e77da0810006e23ff0.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd614e77da0810006e23ff0.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd365f344333f00067aa118.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd365f344333f00067aa118.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd365f144333f00067aa114.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd365f144333f00067aa114.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd614e8d48f840006f14cdd.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd614e8d48f840006f14cdd.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c9e27889b0006b7686a.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c9e27889b0006b7686a.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd617877da0810006e23ffe.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd617877da0810006e23ffe.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd3660444333f00067aa128.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd3660444333f00067aa128.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c9527889b0006b76862.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c9527889b0006b76862.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd365f027889b0006b768a5.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd365f027889b0006b768a5.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c9d44333f00067aa0e4.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c9d44333f00067aa0e4.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c9044333f00067aa0dc.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c9044333f00067aa0dc.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd6139cd48f840006f14cc1.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd6139cd48f840006f14cc1.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd6178ed48f840006f14d15.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd6178ed48f840006f14d15.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd6177ed48f840006f14d11.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd6177ed48f840006f14d11.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd4a18b44333f00067aaddb.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd4a18b44333f00067aaddb.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c9844333f00067aa0e0.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c9844333f00067aa0e0.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd4a18427889b0006b7758f.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd4a18427889b0006b7758f.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd365fe44333f00067aa11e.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd365fe44333f00067aa11e.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd4a18d27889b0006b77595.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd4a18d27889b0006b77595.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd4a19144333f00067aaddf.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd4a19144333f00067aaddf.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd627827da0810006e240c8.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd627827da0810006e240c8.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd3660044333f00067aa122.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd3660044333f00067aa122.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd365fe44333f00067aa11c.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd365fe44333f00067aa11c.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd614367da0810006e23fe0.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd614367da0810006e23fe0.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd4a19644333f00067aade3.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd4a19644333f00067aade3.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd4a19444333f00067aade1.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd4a19444333f00067aade1.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c9c27889b0006b76868.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c9c27889b0006b76868.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd4a18e44333f00067aaddd.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd4a18e44333f00067aaddd.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c9e44333f00067aa0e6.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c9e44333f00067aa0e6.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd4a19327889b0006b77597.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd4a19327889b0006b77597.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd365f244333f00067aa116.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd365f244333f00067aa116.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd61594d48f840006f14cf0.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd61594d48f840006f14cf0.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd35c9a27889b0006b76866.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd35c9a27889b0006b76866.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd365fc27889b0006b768af.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd365fc27889b0006b768af.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd61435d48f840006f14cd6.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd61435d48f840006f14cd6.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd617817da0810006e23ffc.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd617817da0810006e23ffc.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd365e244333f00067aa10e.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd365e244333f00067aa10e.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd6276ed48f840006f14dde.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd6276ed48f840006f14dde.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd365f944333f00067aa11a.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd365f944333f00067aa11a.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd62761d48f840006f14dda.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd62761d48f840006f14dda.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd62779d48f840006f14de0.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd62779d48f840006f14de0.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd616657da0810006e23ff5.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd616657da0810006e23ff5.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd365ee44333f00067aa112.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd365ee44333f00067aa112.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd4a19944333f00067aade5.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd4a19944333f00067aade5.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd3660127889b0006b768b3.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd3660127889b0006b768b3.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd365ec44333f00067aa110.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd365ec44333f00067aa110.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd365f527889b0006b768a7.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd365f527889b0006b768a7.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd4a18527889b0006b77591.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd4a18527889b0006b77591.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd6277c7da0810006e240c6.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd6277c7da0810006e240c6.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F1/path_data_files/5dd61595d48f840006f14cf2.txt' -> '/content/indoor-location-competition/data/site2/F1/path_data_files/5dd61595d48f840006f14cf2.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F2' -> '/content/indoor-location-competition/data/site2/F2'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F2/floor_info.json' -> '/content/indoor-location-competition/data/site2/F2/floor_info.json'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F2/floor_image.png' -> '/content/indoor-location-competition/data/site2/F2/floor_image.png'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F2/geojson_map.json' -> '/content/indoor-location-competition/data/site2/F2/geojson_map.json'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F2/path_data_files' -> '/content/indoor-location-competition/data/site2/F2/path_data_files'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F2/path_data_files/5dd36cb827889b0006b768d8.txt' -> '/content/indoor-location-competition/data/site2/F2/path_data_files/5dd36cb827889b0006b768d8.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F2/path_data_files/5dd3792c44333f00067aa1c3.txt' -> '/content/indoor-location-competition/data/site2/F2/path_data_files/5dd3792c44333f00067aa1c3.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site2/F2/path_data_files/5dd3791327889b0006b76907.txt' -> '/content/indoor-location-competition/data/site2/F2/path_data_files/5dd3791327889b0006b76907.txt'
# ...
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f0f9191710006b575fd.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f0f9191710006b575fd.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f079191710006b575f1.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f079191710006b575f1.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6573c5b77e0006b17932.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6573c5b77e0006b17932.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6552c5b77e0006b17914.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6552c5b77e0006b17914.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb65789191710006b575d5.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb65789191710006b575d5.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6ebac5b77e0006b1793e.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6ebac5b77e0006b1793e.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f149191710006b57601.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f149191710006b57601.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb655d9191710006b575b9.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb655d9191710006b575b9.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6548c5b77e0006b1790a.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6548c5b77e0006b1790a.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f0d9191710006b575f9.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f0d9191710006b575f9.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f00c5b77e0006b17949.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f00c5b77e0006b17949.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddba4ebc5b77e0006b17a2c.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddba4ebc5b77e0006b17a2c.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb654bc5b77e0006b1790e.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb654bc5b77e0006b1790e.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb65369191710006b5759f.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb65369191710006b5759f.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb65649191710006b575c1.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb65649191710006b575c1.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb653fc5b77e0006b17906.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb653fc5b77e0006b17906.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb656fc5b77e0006b1792e.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb656fc5b77e0006b1792e.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb654fc5b77e0006b17912.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb654fc5b77e0006b17912.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb653c9191710006b575a3.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb653c9191710006b575a3.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f129191710006b575ff.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f129191710006b575ff.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddba4ea9191710006b576e2.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddba4ea9191710006b576e2.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb653d9191710006b575a5.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb653d9191710006b575a5.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f09c5b77e0006b17953.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f09c5b77e0006b17953.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6561c5b77e0006b17920.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6561c5b77e0006b17920.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb655b9191710006b575b7.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb655b9191710006b575b7.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6ec9c5b77e0006b17942.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6ec9c5b77e0006b17942.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f0f9191710006b575fb.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f0f9191710006b575fb.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddba3eec5b77e0006b17a1f.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddba3eec5b77e0006b17a1f.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddba2bc9191710006b576de.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddba2bc9191710006b576de.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f01c5b77e0006b1794b.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f01c5b77e0006b1794b.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f12c5b77e0006b1795b.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f12c5b77e0006b1795b.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb65519191710006b575af.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb65519191710006b575af.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb656cc5b77e0006b1792a.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb656cc5b77e0006b1792a.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f019191710006b575eb.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f019191710006b575eb.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f08c5b77e0006b17951.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f08c5b77e0006b17951.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb65679191710006b575c5.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb65679191710006b575c5.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb65459191710006b575ad.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb65459191710006b575ad.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f0d9191710006b575f7.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f0d9191710006b575f7.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb654ac5b77e0006b1790c.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb654ac5b77e0006b1790c.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb65799191710006b575d7.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb65799191710006b575d7.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddba2bbc5b77e0006b17a10.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddba2bbc5b77e0006b17a10.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f0c9191710006b575f5.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f0c9191710006b575f5.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f09c5b77e0006b17955.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f09c5b77e0006b17955.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f0cc5b77e0006b17959.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f0cc5b77e0006b17959.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f0a9191710006b575f3.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f0a9191710006b575f3.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb65579191710006b575b3.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb65579191710006b575b3.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddba2b69191710006b576d6.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddba2b69191710006b576d6.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb65629191710006b575bf.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb65629191710006b575bf.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6538c5b77e0006b17904.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6538c5b77e0006b17904.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb655cc5b77e0006b1791a.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb655cc5b77e0006b1791a.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f1bc5b77e0006b17967.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f1bc5b77e0006b17967.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6ebfc5b77e0006b17940.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6ebfc5b77e0006b17940.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb657ac5b77e0006b1793a.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb657ac5b77e0006b1793a.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f199191710006b57609.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f199191710006b57609.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb65409191710006b575a9.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb65409191710006b575a9.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddba2bcc5b77e0006b17a12.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddba2bcc5b77e0006b17a12.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f199191710006b57607.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6f199191710006b57607.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb656b9191710006b575c7.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb656b9191710006b575c7.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6574c5b77e0006b17934.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6574c5b77e0006b17934.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb655ec5b77e0006b1791c.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb655ec5b77e0006b1791c.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5ddb6effc5b77e0006b17947.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5ddb6effc5b77e0006b17947.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5de8ec02376b9d0006fdaa8d.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5de8ec02376b9d0006fdaa8d.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5de8efda552b1a0006d287b7.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5de8efda552b1a0006d287b7.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5de8efc61ba5a200068722b7.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5de8efc61ba5a200068722b7.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5de8ebff1ba5a200068722a1.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5de8ebff1ba5a200068722a1.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5de8ec021ba5a200068722a3.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5de8ec021ba5a200068722a3.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5de8a9fd7491b00006eaafc4.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5de8a9fd7491b00006eaafc4.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5de8a9e57491b00006eaafc2.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5de8a9e57491b00006eaafc2.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5de8efca1ba5a200068722b9.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5de8efca1ba5a200068722b9.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5de8ec0b1ba5a200068722a5.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5de8ec0b1ba5a200068722a5.txt'
# '/content/drive/MyDrive/indoor-location-competition/data/site1/F4/path_data_files/5de8a9c77491b00006eaafc0.txt' -> '/content/indoor-location-competition/data/site1/F4/path_data_files/5de8a9c77491b00006eaafc0.txt'
# '/content/drive/MyDrive/indoor-location-competition/ILN_632_fold0_submission.csv' -> '/content/indoor-location-competition/ILN_632_fold0_submission.csv'
# '/content/drive/MyDrive/indoor-location-competition/ILN_632_fold_all_submission.csv' -> '/content/indoor-location-competition/ILN_632_fold_all_submission.csv'
# '/content/drive/MyDrive/indoor-location-competition/_history_ILN_632_fold0_latest.json' -> '/content/indoor-location-competition/_history_ILN_632_fold0_latest.json'
# '/content/drive/MyDrive/indoor-location-competition/_history_ILN_632_fold1_latest.json' -> '/content/indoor-location-competition/_history_ILN_632_fold1_latest.json'
# '/content/drive/MyDrive/indoor-location-competition/final_model.pth' -> '/content/indoor-location-competition/final_model.pth'

# %%
cd /content/indoor-location-competition
# Out:
# /content/indoor-location-competition

# %%
import sys
sys.path.append('../input/iln-dataset/ILN_TOOLS')

import gc, glob, time, pickle, math
import numpy as np
import pandas as pd
from tqdm import tqdm

from visualize_f import visualize_trajectory
import compute_f as F
from scipy.interpolate import interp1d

# %%
file_header = 'ILN_631dat'
input_dir = 'unzip_dir'
floor_map = {"B2":-2, "B1":-1,
             "F1":0, "F2":1, "F3":2, "F4":3, "F5":4,
             "F6":5, "F7":6, "F8":7, "F9":8,
             "1F":0, "2F":1, "3F":2, "4F":3, "5F":4,
             "6F":5, "7F":6, "8F":7, "9F":8}
site_list = ['5d2709a003f801723c3251bf','5a0546857ecc773753327266',
             '5c3c44b80379370013e0fd2b','5d2709b303f801723c327472',
             '5d2709bb03f801723c32852c','5d2709c303f801723c3299ee',
             '5d2709d403f801723c32bd39','5d2709e003f801723c32d896',
             '5d27075f03f801723c2e360f','5d27096c03f801723c31e5e0',
             '5d27097f03f801723c320d97','5d27099f03f801723c32511d',
             '5da138b74db8ce0c98bd4774','5da958dd46f8266d0737457b',
             '5da1382d4db8ce0c98bbe92e','5da1383b4db8ce0c98bc11ab',
             '5da1389e4db8ce0c98bd0547','5da138274db8ce0c98bbd3d2',
             '5da138314db8ce0c98bbf3a0','5da138364db8ce0c98bc00f1',
             '5da138754db8ce0c98bca82f','5da138764db8ce0c98bcaa46',
             '5dbc1d84c1eb61796cf7c010','5dc8cea7659e181adb076a3f']

# %%
'''
Modify the host's code "read_data_file" function in "io_f.py"
for dealing with the malformed data etc.
'''

from dataclasses import dataclass

@dataclass
class ReadData:
    acce: np.ndarray
    acce_uncali: np.ndarray
    gyro: np.ndarray
    gyro_uncali: np.ndarray
    magn: np.ndarray
    magn_uncali: np.ndarray
    ahrs: np.ndarray
    wifi: np.ndarray
    ibeacon: np.ndarray
    waypoint: np.ndarray

def split_list_as_req(line_data):
    redo = False
    data_BU = []
    header_list = [i for i, itm in enumerate(line_data) if 'TYPE_' in itm]
    if len(header_list) > 1:
        data_BU = [line_data[header_list[1]-1][-13:]] + line_data[header_list[1]:]
        line_data[header_list[1]-1] = line_data[header_list[1]-1][:-13]
        line_data = line_data[:header_list[1]]
        redo = True
    return redo, line_data, data_BU

def read_data_file(data_filename):
    acce = []
    acce_uncali = []
    gyro = []
    gyro_uncali = []
    magn = []
    magn_uncali = []
    ahrs = []
    wifi = []
    ibeacon = []
    waypoint = []

    with open(data_filename, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    i = 0
    redo = False
    while i < len(lines):
        if not redo:
            line_data = lines[i]
            line_data = line_data.strip()
            if not line_data or line_data[0] == '#':
                i += 1
                continue
            line_data = line_data.split('\t')
        else:
            line_data = data_BU
            redo = False

        redo, line_data, data_BU = split_list_as_req(line_data)

        if line_data[1] == 'TYPE_ACCELEROMETER':
            try:
                acce.append([int(line_data[0]), float(line_data[2]), float(line_data[3]), float(line_data[4])])
            except ValueError:
                print(data_filename)
                print(line_data)

        elif line_data[1] == 'TYPE_ACCELEROMETER_UNCALIBRATED':
            acce_uncali.append([int(line_data[0]), float(line_data[2]), float(line_data[3]), float(line_data[4])])

        elif line_data[1] == 'TYPE_GYROSCOPE':
            gyro.append([int(line_data[0]), float(line_data[2]), float(line_data[3]), float(line_data[4])])

        elif line_data[1] == 'TYPE_GYROSCOPE_UNCALIBRATED':
            gyro_uncali.append([int(line_data[0]), float(line_data[2]), float(line_data[3]), float(line_data[4])])

        elif line_data[1] == 'TYPE_MAGNETIC_FIELD':
            magn.append([int(line_data[0]), float(line_data[2]), float(line_data[3]), float(line_data[4])])

        elif line_data[1] == 'TYPE_MAGNETIC_FIELD_UNCALIBRATED':
            magn_uncali.append([int(line_data[0]), float(line_data[2]), float(line_data[3]), float(line_data[4])])

        elif line_data[1] == 'TYPE_ROTATION_VECTOR':
            ahrs.append([int(line_data[0]), float(line_data[2]), float(line_data[3]), float(line_data[4])])

        elif line_data[1] == 'TYPE_WIFI':
            sys_ts = line_data[0]
            ssid = line_data[2]
            bssid = line_data[3]
            rssi = line_data[4]
            lastseen_ts = line_data[6]
            frequency = line_data[5]
            wifi_data = [sys_ts, ssid, bssid, rssi, lastseen_ts, frequency]
            wifi.append(wifi_data)

        elif line_data[1] == 'TYPE_BEACON':
            ts = line_data[0]
            uuid = line_data[2]
            major = line_data[3]
            minor = line_data[4]
            rssi = line_data[6]
            txpow = line_data[5]
            distance = line_data[7]
            mac = line_data[8]
            if len(line_data)>9:
                ts_copy = line_data[9]
            else:
                ts_copy = ts
            ibeacon_data = [ts, '_'.join([uuid, major, minor]), rssi,
                            txpow, distance, mac, ts_copy]
            ibeacon.append(ibeacon_data)

        elif line_data[1] == 'TYPE_WAYPOINT':
            waypoint.append([int(line_data[0]), float(line_data[2]), float(line_data[3])])

        if not redo:
            i += 1

    acce = np.array(acce)
    acce_uncali = np.array(acce_uncali)
    gyro = np.array(gyro)
    gyro_uncali = np.array(gyro_uncali)
    magn = np.array(magn)
    magn_uncali = np.array(magn_uncali)
    ahrs = np.array(ahrs)
    wifi = np.array(wifi)
    ibeacon = np.array(ibeacon)
    waypoint = np.array(waypoint)

    return ReadData(acce, acce_uncali, gyro, gyro_uncali, magn, magn_uncali, ahrs, wifi, ibeacon, waypoint)

# %% [markdown]
# "test_site_dict.pkl" in the below cell is the dictionary consists of wifi bssid and the ibeacon MAC address in the test data, and created with [this notebook](https://www.kaggle.com/horsek/ilnpre1-create-testsitedict).
#
# "df_TestTimeLag" in the below cell is a time lag table for each path in the test data, and created with [this notebook](https://www.kaggle.com/horsek/iln-preprocess-time-lag-table-of-test-data).

# %%
with open("test_site_dict.pkl", "rb") as f:
    test_site_dict = pickle.load(f)
df_TestTimeLag = pd.read_csv('test_ts_lag.csv',index_col=0)

# %%
'''
Create sequence of time & relative position data for each path
Outputs are as follows:
  PathSeq_t: timestamp
  PathSeq_l: length position (cumulative summation (cumsum) of walking distance)
             at each timestamp
  PathSeq_rx, PathSeq_ry: relative position
'''
def Path_Sequence(PathData):
    step_timestamps, step_indexs, step_acce_max_mins = \
        F.compute_steps(PathData.acce)
    headings = F.compute_headings(PathData.ahrs)
    stride_lengths = F.compute_stride_length(step_acce_max_mins)
    step_headings = F.compute_step_heading(step_timestamps, headings)
    PathSeq_t = stride_lengths[:,0]
    PathSeq_t = np.insert(PathSeq_t, 0,
                          PathData.acce[0,0]).astype('int64')
    PathSeq_l = stride_lengths[:,1].cumsum()
    PathSeq_l = np.append(np.array(0),PathSeq_l)

    rel_pos = F.compute_rel_positions(stride_lengths, step_headings)
    PathSeq_rx = np.append(np.array(0),rel_pos[:,1]).cumsum()
    PathSeq_ry = np.append(np.array(0),rel_pos[:,2]).cumsum()
    return PathSeq_t, PathSeq_l, PathSeq_rx, PathSeq_ry

# %%
'''
Create pd.DataFrame of wifi signal data for each path
Basic format is the same as that created with Kouki's great notebook.
(https://www.kaggle.com/kokitanisaka/create-unified-wifi-features-example)
- rows: timestamp (or corresponding Length position)
- columns: signal id and strength, which are sorted by strength at the same timestamp
'''
def dfSignalSequence(df_sign, ref_time, id_list,
                     id_, values, tslabel, n_in_seq):

    ''' Drop the data out of "tslabel" range '''
    mask = df_sign[id_].apply(lambda x: x in id_list)
    mask &= (df_sign[tslabel] >= ref_time[0])
    mask &= (df_sign[tslabel] <= ref_time[-1])
    df_sign = df_sign[mask]
    if df_sign.shape[0]==0:
        return

    ''' Drop the data before the previous timestamp '''
    df_tmp = pd.DataFrame(df_sign[tslabel].unique(),columns=[tslabel])
    df_tmp['last_ts'] = np.append(ref_time[0],
                                  df_tmp[tslabel].values[:-1])
    df_sign = df_sign.merge(df_tmp, how='left', on=tslabel)
    del df_tmp; gc.collect()
    df_sign = df_sign[df_sign['lastseen_ts']>=df_sign['last_ts']]
    df_sign.drop('last_ts', axis=1, inplace=True)
    if df_sign.shape[0]==0:
        return

    ''' create pivot table '''
    df_sign.set_index(tslabel, inplace=True)
    df_pivot = df_sign.pivot_table(index=df_sign.index,
                                   columns=id_, values=values,
                                   aggfunc=max)
    feat = []
    for i in range(df_pivot.shape[0]):
        tmp = df_pivot.iloc[i,:].sort_values(ascending=False)[:n_in_seq]
        if tmp.shape[0]!=n_in_seq:
            n_col = tmp.shape[0]
            add_col = list(set(id_list)-set(tmp.index))[:n_in_seq-n_col]
            tmp = pd.concat([tmp, pd.Series(np.nan, index=add_col)])
            assert tmp.shape[0]==n_in_seq
        tmp = tmp.reset_index().values.T.reshape(-1)
        feat.append(tmp)
    feat = np.stack(feat,axis=1).T
    df_out = pd.DataFrame(feat,
                          columns=[f'id_{i}' for i in range(n_in_seq)]
                                 +[f'strength_{i}' for i in range(n_in_seq)])
    df_out[tslabel] = df_pivot.index
    df_out.set_index(tslabel, drop=True, inplace=True)
    return df_out

# %%
''' Retrieve the Site ID from txt file '''
def SiteID(txt):
    p1 = txt[1].find('SiteID:')+7
    p2 = txt[1].find('\tSiteName:')
    assert p1!=-1+7 and p2!=-1, 'SiteID not found'
    return txt[1][p1:p2]

# %%
def headings_from_magn(PathData):
    mag_df = pd.DataFrame(PathData.magn)
    mag_df.columns = ["timestamp","x","y","z"]
    acce_df = pd.DataFrame(PathData.acce)
    acce_df.columns = ["timestamp","ax","ay","az"]
    mag_df = pd.merge(mag_df,acce_df,on="timestamp").dropna()

    m_trans = 0
    time_di_list = []
    for i in mag_df.iterrows():

        ''' https://www.kaggle.com/museas/with-magn-cost-minimization '''
        gx,gy,gz = i[1][1],i[1][2],i[1][3]
        ax,ay,az = i[1][4],i[1][5],i[1][6]
        roll = math.atan2(ay,az)
        pitch = math.atan2(-1*ax , (ay * math.sin(roll) + az * math.cos(roll)))
        q = m_trans - math.atan2(
            (gz*math.sin(roll)-gy*math.cos(roll)),(gx*math.cos(pitch) + gy*math.sin(roll)*math.sin(pitch) + gz*math.sin(pitch)*math.cos(roll))
        ) -np.pi/2
        q = (q+np.pi)%(2*np.pi)-np.pi

        ''' The following is a different calculation for verification '''
#         mag, acce = i[1][1:4].values, i[1][4:7].values
#         axsz = acce/np.linalg.norm(acce)
#         axsy = mag/np.linalg.norm(mag)
#         axsy -= np.sum(axsy*axsz) * axsz
#         axsy = axsy/np.linalg.norm(axsy)
#         axsx = np.cross(axsy, axsz)
#         q1 = np.arctan2(axsx[1],axsy[1])
#         q1 = (q1+np.pi)%(2*np.pi)-np.pi

        time_di_list.append((i[1][0],q))
    return np.array(time_di_list)

def add_IMU(PathData, df_inpt, time_delta=0):

    headmagn = headings_from_magn(PathData)
    df_IMU = pd.DataFrame(PathData.gyro,columns=['IMU_ts','gyro_x','gyro_y','gyro_z'])
    df_IMU['IMU_ts'] = (df_IMU['IMU_ts']+time_delta).astype('int64')
#     assert (df_IMU['IMU_ts'].values==headmagn[:,0]).all()
#     assert (df_IMU['IMU_ts'].values==PathData.acce[:,0]).all()
#     assert (df_IMU['IMU_ts'].values==PathData.ahrs[:,0]).all()
    df_IMU['head_magn_x'] = np.sin(headmagn[:,1])
    df_IMU['head_magn_y'] = np.cos(headmagn[:,1])
    df_IMU[['acce_x','acce_y','acce_z']] = PathData.acce[:,1:]
    df_IMU[['ahrs_x','ahrs_y','ahrs_z']] = PathData.ahrs[:,1:]
    df_IMU[['magn_x','magn_y','magn_z']] = PathData.magn[:,1:]

    ''' set window label '''
    grp_ts = df_inpt.index.name
    df_IMU = pd.concat([pd.DataFrame([df_inpt.index]*2,index=['IMU_ts',grp_ts]).T,
                        df_IMU], axis=0)
    df_IMU = df_IMU.sort_values('IMU_ts')
    df_IMU[grp_ts].fillna(method='bfill',inplace=True)
    df_IMU.dropna(inplace=True)
    df_IMU[grp_ts] = df_IMU[grp_ts].astype('int64')
    df_IMU.drop('IMU_ts', axis=1, inplace=True)

    ''' grouping by timestamp of wifi data '''
    gdf_IMU = pd.concat([df_IMU.groupby(grp_ts).mean().add_suffix('_mean'),
                         df_IMU.groupby(grp_ts).std().add_suffix('_std'),
                         df_IMU.groupby(grp_ts).max().add_suffix('_max'),
                         df_IMU.groupby(grp_ts).min().add_suffix('_min'),
                         df_IMU.groupby(grp_ts).skew().add_suffix('_skew')],axis=1)

    return df_inpt.merge(gdf_IMU, how='left', left_index=True, right_index=True)

# %%
tmp_list = []

# %%
mkdir unzip_dir

# %%
# prompt: unzip loacation file to unzip_dir

# !unzip -d unzip_dir indoor-location-navigation.zip

# %%
''' train data processing '''
for i_site, site in enumerate(site_list):

    print(f'========== {i_site+1}/{len(site_list)} ==========')
    print(f'site: {site}')
    test_wifi = sorted(test_site_dict[site]['wifi'])
    print(f'num of wifi BSSID in test set: {len(test_wifi)}')

    AllPathData = []
    floor_dirs = sorted(glob.glob(f'{input_dir}/train/{site}/*'))
    floors = [dir_.split('/')[-1] for dir_ in floor_dirs]

    print(f'floors: {floors}')

    print('\n=== Read Path Data ===')
    time.sleep(1)
    for i, floor_dir_ in enumerate(floor_dirs):
        path_files = sorted(glob.glob(f'{floor_dir_}/*'))
        dic_temp = {}
        for path_file_ in tqdm(path_files, desc=floors[i]):
            path_name = path_file_.split('/')[-1].replace('.txt','')
            dic_temp[path_name] = read_data_file(path_file_)
        AllPathData.append(dic_temp)
    del dic_temp; gc.collect()

    print('\n=== Create features ===')
    time.sleep(1)
    for i_floor, FloorPathData in enumerate(AllPathData):
        for PathName, PathData in tqdm(FloorPathData.items(),
                                       desc=floors[i_floor]):
            ''' Path Sequence '''
            PathSeq_t, PathSeq_l, PathSeq_rx, PathSeq_ry = Path_Sequence(PathData)

            ''' wifi DataFrame '''
            if PathData.wifi.shape[0]==0:
                continue
            df_wifi = pd.DataFrame(PathData.wifi,
                                   columns=['sys_ts','ssid','bssid','rssi',
                                            'lastseen_ts','frequency'])
            df_wifi['sys_ts']=df_wifi['sys_ts'].astype(np.int64)
            df_wifi['lastseen_ts']=df_wifi['lastseen_ts'].astype(np.int64)
            df_wifi['rssi']=df_wifi['rssi'].astype(np.int64)

            ''' Signal Sequence '''
            df_feat = dfSignalSequence(df_wifi, PathSeq_t, test_wifi,
                                       'bssid','rssi','sys_ts',100)
            if df_feat is None:
                continue

            ''' Compute length position & relative position by interpolation '''
            itp_l = interp1d(PathSeq_t, PathSeq_l,
                             fill_value=(PathSeq_l[0],PathSeq_l[-1]),
                             bounds_error=False)
            df_feat['len_pos'] = itp_l(df_feat.index)
            itp_rx = interp1d(PathSeq_t, PathSeq_rx,
                              fill_value=(PathSeq_rx[0],PathSeq_rx[-1]),
                              bounds_error=False)
            itp_ry = interp1d(PathSeq_t, PathSeq_ry,
                              fill_value=(PathSeq_ry[0],PathSeq_ry[-1]),
                              bounds_error=False)
            df_feat['rel_x'] = itp_rx(df_feat.index)
            df_feat['rel_y'] = itp_ry(df_feat.index)

            ''' IMU data '''
            df_feat = add_IMU(PathData, df_feat)

            ''' x, y, floor, labels '''
#             idx = np.abs(PathData.waypoint[:,0:1]-
#                          df_feat.index.values.reshape(1,-1)).argmin(axis=0)
#             df_feat[['x','y']]=PathData.waypoint[idx,1:]

            GT_t, GT_x, GT_y = [PathData.waypoint[:,i] for i in range(3)]
            GT_l = itp_l(GT_t)
            itp_x = interp1d(GT_l, GT_x, fill_value=(GT_x[0],GT_x[-1]),
                             bounds_error=False)
            itp_y = interp1d(GT_l, GT_y, fill_value=(GT_y[0],GT_y[-1]),
                             bounds_error=False)
            df_feat['x'] = itp_x(df_feat['len_pos'])
            df_feat['y'] = itp_y(df_feat['len_pos'])
            df_feat['floor'] = floor_map[floors[i_floor]]
            df_feat['path'] = PathName
            df_feat['site'] = site
            df_feat['train/test'] = 'train'

            tmp_list.append(df_feat)
# Out:
# ========== 1/24 ==========
# site: 5d2709a003f801723c3251bf
# num of wifi BSSID in test set: 885
# floors: ['1F', '2F', '3F', '4F']
#
# === Read Path Data ===
# 1F: 100%|██████████| 123/123 [00:09<00:00, 13.19it/s]
# 2F: 100%|██████████| 102/102 [00:08<00:00, 12.07it/s]
# 3F: 100%|██████████| 25/25 [00:02<00:00, 11.78it/s]
# 4F: 100%|██████████| 60/60 [00:05<00:00, 11.70it/s]
# === Create features ===
# 1F:  55%|█████▌    | 68/123 [00:29<00:27,  2.02it/s]<ipython-input-9-acdeaf03c4b2>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sign.drop('last_ts', axis=1, inplace=True)
# 1F: 100%|██████████| 123/123 [00:55<00:00,  2.22it/s]
# 2F:   1%|          | 1/102 [00:00<00:28,  3.49it/s]<ipython-input-9-acdeaf03c4b2>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sign.drop('last_ts', axis=1, inplace=True)
# 2F:  49%|████▉     | 50/102 [00:23<00:20,  2.49it/s]<ipython-input-9-acdeaf03c4b2>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sign.drop('last_ts', axis=1, inplace=True)
# 2F: 100%|██████████| 102/102 [00:51<00:00,  1.98it/s]
# 3F: 100%|██████████| 25/25 [00:13<00:00,  1.91it/s]
# 4F: 100%|██████████| 60/60 [00:31<00:00,  1.92it/s]
# ========== 2/24 ==========
# site: 5a0546857ecc773753327266
# num of wifi BSSID in test set: 2435
# floors: ['B1', 'F1', 'F2', 'F3', 'F4']
#
# === Read Path Data ===
# B1: 100%|██████████| 109/109 [00:13<00:00,  7.97it/s]
# F1: 100%|██████████| 131/131 [00:17<00:00,  7.48it/s]
# F2: 100%|██████████| 110/110 [00:23<00:00,  4.67it/s]
# F3: 100%|██████████| 78/78 [00:10<00:00,  7.10it/s]
# F4: 100%|██████████| 86/86 [00:19<00:00,  4.34it/s]
# === Create features ===
# B1:   6%|▋         | 7/109 [00:06<01:37,  1.05it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-c88a2199a739> in <cell line: 2>()
#      43
#      44             ''' Signal Sequence '''
# ---> 45             df_feat = dfSignalSequence(df_wifi, PathSeq_t, test_wifi,
#      46                                        'bssid','rssi','sys_ts',100)
#      47             if df_feat is None:
#
# <ipython-input-9-acdeaf03c4b2> in dfSignalSequence(df_sign, ref_time, id_list, id_, values, tslabel, n_in_seq)
#      13     mask &= (df_sign[tslabel] >= ref_time[0])
#      14     mask &= (df_sign[tslabel] <= ref_time[-1])
# ---> 15     df_sign = df_sign[mask]
#      16     if df_sign.shape[0]==0:
#      17         return
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3796         # Do we have a (boolean) 1d indexer?
#    3797         if com.is_bool_indexer(key):
# -> 3798             return self._getitem_bool_array(key)
#    3799
#    3800         # We are left with two options: a single key, and a collection of keys,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    3851         key = check_bool_indexer(self.index, key)
#    3852         indexer = key.nonzero()[0]
# -> 3853         return self._take_with_is_copy(indexer, axis=0)
#    3854
#    3855     def _getitem_multilevel(self, key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _take_with_is_copy(self, indices, axis)
#    3902         result = self._take(indices=indices, axis=axis)
#    3903         # Maybe set copy if we didn't actually change the index.
# -> 3904         if not result._get_axis(axis).equals(self._get_axis(axis)):
#    3905             result._set_is_copy(self)
#    3906         return result
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_axis(self, axis)
#     562         return cls._AXIS_ORDERS[axis_number]
#     563
# --> 564     @final
#     565     def _get_axis(self, axis: Axis) -> Index:
#     566         axis_number = self._get_axis_number(axis)
#
# KeyboardInterrupt:

# %%
''' test data processing '''
print('\n=== Read Path Data ===')
test_files = sorted(glob.glob(f'{input_dir}/test/*.txt'))
TestPathData,TestSiteName = {},{}
time.sleep(1)
for path_file_ in tqdm(test_files):
    path_name = path_file_.split('/')[-1].replace('.txt','')
    TestPathData[path_name] = read_data_file(path_file_)

    with open(path_file_, 'r', encoding="utf-8") as f:
        txt = f.readlines()
    TestSiteName[path_name] = SiteID(txt)

print('\n=== Create features ===')
time.sleep(1)
for PathName, PathData in tqdm(TestPathData.items()):
    site = TestSiteName[PathName]
    test_wifi = sorted(test_site_dict[site]['wifi'])
    time_lag = df_TestTimeLag.loc[PathName,'time_lag']

    ''' Path Sequence '''
    PathSeq_t, PathSeq_l, PathSeq_rx, PathSeq_ry = Path_Sequence(PathData)
    PathSeq_t += time_lag

    ''' wifi DataFrame '''
    if PathData.wifi.shape[0]==0:
        continue
    df_wifi = pd.DataFrame(PathData.wifi,
                           columns=['sys_ts','ssid','bssid','rssi',
                                    'lastseen_ts','frequency'])
    df_wifi['sys_ts']=df_wifi['sys_ts'].astype(np.int64)
    df_wifi['sys_ts'] += time_lag
    df_wifi['lastseen_ts']=df_wifi['lastseen_ts'].astype(np.int64)
    df_wifi['rssi']=df_wifi['rssi'].astype(np.int64)

    ''' Signal Sequence '''
    df_feat = dfSignalSequence(df_wifi, PathSeq_t, test_wifi,
                               'bssid','rssi','sys_ts',100)
    if df_feat is None:
        continue

    ''' Compute length position & relative position by interpolation '''
    itp_l = interp1d(PathSeq_t, PathSeq_l,
                     fill_value=(PathSeq_l[0],PathSeq_l[-1]),
                     bounds_error=False)
    df_feat['len_pos'] = itp_l(df_feat.index)
    itp_rx = interp1d(PathSeq_t, PathSeq_rx,
                      fill_value=(PathSeq_rx[0],PathSeq_rx[-1]),
                      bounds_error=False)
    itp_ry = interp1d(PathSeq_t, PathSeq_ry,
                      fill_value=(PathSeq_ry[0],PathSeq_ry[-1]),
                      bounds_error=False)
    df_feat['rel_x'] = itp_rx(df_feat.index)
    df_feat['rel_y'] = itp_ry(df_feat.index)

    ''' IMU data '''
    df_feat = add_IMU(PathData, df_feat, time_lag)

    ''' x, y, floor, labels '''
    df_feat[['x','y']] = np.nan
    df_feat['floor'] = np.nan
    df_feat['path'] = PathName
    df_feat['site'] = site
    df_feat['train/test'] = 'test'

    tmp_list.append(df_feat)
# Out:
# === Read Path Data ===
# 100%|██████████| 626/626 [04:49<00:00,  2.16it/s]
# === Create features ===
#   1%|          | 4/626 [00:05<14:40,  1.42s/it]<ipython-input-9-acdeaf03c4b2>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sign.drop('last_ts', axis=1, inplace=True)
#  23%|██▎       | 145/626 [04:15<10:29,  1.31s/it]<ipython-input-9-acdeaf03c4b2>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sign.drop('last_ts', axis=1, inplace=True)
#  30%|██▉       | 187/626 [05:32<15:34,  2.13s/it]<ipython-input-9-acdeaf03c4b2>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sign.drop('last_ts', axis=1, inplace=True)
#  30%|███       | 189/626 [05:35<13:36,  1.87s/it]<ipython-input-9-acdeaf03c4b2>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sign.drop('last_ts', axis=1, inplace=True)
#  48%|████▊     | 302/626 [08:34<10:30,  1.95s/it]<ipython-input-9-acdeaf03c4b2>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sign.drop('last_ts', axis=1, inplace=True)
#  57%|█████▋    | 357/626 [10:24<10:02,  2.24s/it]

# %%
df_wifi_all = pd.concat(tmp_list)
df_wifi_all.reset_index(inplace=True)

#null check
df_wifi_all[[f'id_{i}' for i in range(100)]].isnull().any().any()
# Out:
# False

# %%
with open(f'{file_header}_df_wifi_all.pkl','wb') as f:
    pickle.dump(df_wifi_all, f)
